# %%
import pandas as pd
d = {'col1':[1,2], 'col2':[3,5]}
df = pd.DataFrame(data = d)
print(df)
print(df.dtypes)
# Out:
#    col1  col2
# 0     1     3
# 1     2     5
# col1    int64
# col2    int64
# dtype: object

# %%
import pandas as pd
import numpy as np

def carre(n):
    return n*n

df2 = pd.DataFrame(np.random.randint(low =0, high =16,size=(5,5)), columns=['a','b','c','d','e'])
df2 
df2_trans = df2.T # transpose of te matrice
df2_trans
# Out:
#     0   1   2  3   4
# a   6   8   3  2   9
# b   9   1  14  1  13
# c  13  13   0  5   1
# d  12  11  11  3   1
# e   3  11   7  2   0

# %%
df2_singlesvalues = df2.at
df2_singlesvalues
df2
# Out:
#    a   b   c   d   e
# 0  6   9  13  12   3
# 1  8   1  13  11  11
# 2  3  14   0  11   7
# 3  2   1   5   3   2
# 4  9  13   1   1   0

# %%
df2mul = df2.apply(carre)
dfap = df2.append(df2mul)
#df2.applymap(lambda: x^2)
dfap
# Out:
#     a    b    c    d    e
# 0   8   12    1   10   13
# 1   7    6   13    4   13
# 2   3    8    0    7   15
# 3   2    2    1   15   11
# 4   4    1    3   10    4
# 0  64  144    1  100  169
# 1  49   36  169   16  169
# 2   9   64    0   49  225
# 3   4    4    1  225  121
# 4  16    1    9  100   16

# %%
import pandas as pd
import numpy as np
bdf = pd.DataFrame(np.random.randn(10,4),columns=['Col1', 'Col2', 'Col3', 'Col4'])

boxplot = bdf.boxplot(column=['Col1', 'Col2', 'Col3'])
