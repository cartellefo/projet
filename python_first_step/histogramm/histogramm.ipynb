# %% [markdown]
# # hello jupyter

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
# %matplotlib inline
from random import gauss
x10 = [gauss(100,15) for i in range(10)]
x100 = [gauss(100,15) for i in range(100)]
x1000 = [gauss(100,15) for i in range(1000)]
x10000 = [gauss(100,15) for i in range(1000)]

#mean1 = np.mean(x10)
#mean2 = np.mean(x100)

#std_dev1=np.std(x10)

num_bins = 50
n, bins, patches = plt.hist(x10, num_bins, normed=1, facecolor='green', alpha=0.5)
n, bins, patches = plt.hist(x100, num_bins, normed=1, facecolor='red', alpha=0.5)
n, bins, patches = plt.hist(x1000, num_bins, normed=1, facecolor='blue', alpha=0.5)
n, bins, patches = plt.hist(x10000, num_bins, normed=1, facecolor='yellow', alpha=0.5)

#gauss1 = mlab.normpdf(bins, mean1, std_dev1)
#plt.plot(bins, gauss1, 'k', linewidth=2)
#plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt



data = norm.rvs(10.0, 2.5, size=500)

# Fit a normal distribution to the data:
mu, std = norm.fit(data)

# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='g')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)


mu = 100  
sigma = 15  
x = mu + sigma * np.random.randn(437)
num_bins = 50
fig, ax = plt.subplots()
n, bins, patches = ax.hist(x, num_bins, density=1,label="data")
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--', label="model")
ax.set_xlabel('axis of abscissae')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of gauss: $\mu=100$, $\sigma=15$')
fig.tight_layout()
plt.legend()
plt.savefig("histnotcenter.pdf")
plt.show()

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

#y = np.random.standard_normal(10000) direct alternativ to generate a normal number
#data = py.hist(y, bins = 100)

mu = 0  
sigma = 1  
x = mu + sigma * np.random.randn(437)
num_bins = 50
fig, ax = plt.subplots()
n, bins, patches = ax.hist(x, num_bins, density=1,label="data")
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--', label="model")
ax.set_xlabel('axis of abscissae')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of gauss: $\mu=0$, $\sigma=1$')
fig.tight_layout()
plt.legend()
plt.savefig("histogramme.pdf")
plt.show()

# %%
# 3D Plot normal random
x = 1
